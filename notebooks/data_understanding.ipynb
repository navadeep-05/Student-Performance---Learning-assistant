# %%
# This notebook is created for understanding data, 
# cleaning it and analyzing it

# %%
pip install numpy pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\navad\Music\AI-powered Student Assistant\data\raw\student_learning_data_raw.csv")

# %%
df.head()
# Out:
#   student_id  age  gender department  semester  attendance_pct  \
# 0  STU100001   22    Male        ECE         5            66.1
# 1  STU100002   18  Female        ECE         8            89.1
# 2  STU100003   23  Female        ECE         5            76.9
# 3  STU100004   22    Male        ECE         4            89.0
# 4  STU100005   23  Female       MECH         4            62.0
#
#    assignment_avg  assignment_completion_pct  quiz_avg  quiz_attempts  ...  \
# 0            74.9                       44.8      60.1             12  ...
# 1            59.8                       69.1      54.5             12  ...
# 2            68.6                       96.7      79.3             14  ...
# 3            78.8                       52.1      49.8             12  ...
# 4            47.7                       47.7      35.3             10  ...
#
#    video_completion_pct  previous_gpa  previous_failures  late_assignments  \
# ...

# %%
df.shape
# Out:
# (8020, 25)

# %%
df.columns.tolist()
# Out:
# ['student_id',
#  'age',
#  'gender',
#  'department',
#  'semester',
#  'attendance_pct',
#  'assignment_avg',
#  'assignment_completion_pct',
#  'quiz_avg',
#  'quiz_attempts',
#  'study_hours_week',
#  'participation_score',
#  'lms_login_count',
#  'lms_active_days',
#  'resources_accessed',
#  'video_completion_pct',
#  'previous_gpa',
#  'previous_failures',
#  'late_assignments',
#  'discussion_participation',
#  'support_requested',
#  'midterm_score',
#  'final_score',
#  'performance_level',
#  'risk_level']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8020 entries, 0 to 8019
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   student_id                 8020 non-null   str
#  1   age                        8020 non-null   int64
#  2   gender                     8020 non-null   str
#  3   department                 8020 non-null   str
#  4   semester                   8020 non-null   int64
#  5   attendance_pct             7940 non-null   float64
#  6   assignment_avg             7940 non-null   float64
#  7   assignment_completion_pct  8020 non-null   float64
#  8   quiz_avg                   7940 non-null   float64
#  9   quiz_attempts              8020 non-null   int64
#  10  study_hours_week           7940 non-null   float64
#  11  participation_score        7940 non-null   float64
#  12  lms_login_count            8020 non-null   int64
# ...

# %%
df.describe()
# Out:
#                age     semester  attendance_pct  assignment_avg  \
# count  8020.000000  8020.000000     7940.000000     7940.000000
# mean     21.010723     4.972693       73.838199       63.534257
# std       1.980233     1.990219       10.770903       12.905288
# min      18.000000     2.000000       35.000000       20.500000
# 25%      19.000000     3.000000       66.700000       54.900000
# 50%      21.000000     5.000000       73.900000       63.700000
# 75%      23.000000     7.000000       81.400000       72.300000
# max      24.000000     8.000000      100.000000      100.000000
#
#        assignment_completion_pct     quiz_avg  quiz_attempts  \
# count                8020.000000  7940.000000    8020.000000
# mean                   70.360249    59.330730      11.779551
# std                    12.242731    13.966999       3.163111
# min                    27.800000    15.000000       1.000000
# 25%                    62.000000    49.800000      10.000000
# ...

# %%
#CHECK MISSING VALUES
df.isnull().sum()
# Out:
# student_id                    0
# age                           0
# gender                        0
# department                    0
# semester                      0
# attendance_pct               80
# assignment_avg               80
# assignment_completion_pct     0
# quiz_avg                     80
# quiz_attempts                 0
# study_hours_week             80
# participation_score          80
# lms_login_count               0
# lms_active_days              82
# resources_accessed            0
# video_completion_pct         80
# previous_gpa                 81
# previous_failures             0
# late_assignments              0
# discussion_participation      0
# support_requested             0
# midterm_score                80
# final_score                   0
# performance_level             0
# risk_level                    0
# dtype: int64

# %%
#check duplicate rows
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
# Check our target distribution
df['risk_level'].value_counts()
# Out:
# risk_level
# Medium    3485
# Low       2622
# High      1913
# Name: count, dtype: int64

# %%
# Tells us how many students belong to:    
# High     Medium     Low              in form of probability
df['risk_level'].value_counts(normalize=True) * 100
# Out:
# risk_level
# Medium    43.453865
# Low       32.693267
# High      23.852868
# Name: proportion, dtype: float64

# %%
# This understands the relationship between risk and performance
df.groupby("risk_level")["final_score"].mean()                          # this shows that there is low relationship percentage between risk and performance
# Out:
# risk_level
# High      42.514323
# Low       73.047292
# Medium    57.626600
# Name: final_score, dtype: float64

# %%
#Explores attendance
df["attendance_pct"].describe()

#explroes relationship b/w risk and attendance
df.groupby("risk_level")["attendance_pct"].mean()

#Do high-risk students generally have lower attendance?   yes
# Out:
# risk_level
# High      64.285699
# Low       81.702118
# Medium    73.147178
# Name: attendance_pct, dtype: float64

# %%
# Explore quiz performance
df.groupby("risk_level")["quiz_avg"].mean()
# Out:
# risk_level
# High      47.104902
# Low       69.661749
# Medium    58.278532
# Name: quiz_avg, dtype: float64

# %%
#Explore assignment performance
df.groupby("risk_level")["assignment_avg"].mean()
# Out:
# risk_level
# High      52.048573
# Low       73.232859
# Medium    62.526500
# Name: assignment_avg, dtype: float64

# %%
df.groupby("risk_level")["study_hours_week"].mean()
# Out:
# risk_level
# High       9.792093
# Low       15.997921
# Medium    12.912449
# Name: study_hours_week, dtype: float64

# %%
df['risk_level'].value_counts().plot(
    kind='bar',
    title='Student Risk Distribution'
)

plt.xlabel("Risk Level")
plt.ylabel("Number of Students")
plt.show()
